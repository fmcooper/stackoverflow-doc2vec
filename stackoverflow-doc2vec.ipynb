# %% [markdown]
# # Stackoverflow Doc2Vec
#
# <a href="https://colab.research.google.com/github/fmcooper/stackoverflow-doc2vec/blob/master/stackoverflow-doc2vec.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>
#
# Data from: https://www.kaggle.com/stackoverflow/pythonquestions#Tags.csv
#
# ---

# %%
import sys
import numpy as np
import pandas as pd
from time import time
import codecs # handles errors on data import
import gensim
from gensim.models import Word2Vec, Doc2Vec
from gensim.models.doc2vec import Doc2Vec, TaggedDocument
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
import sklearn
import nltk
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import logging # to show progress of training model
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)



print("\n---------- versions ----------\n")
print("python version: " + sys.version)
print("pandas version: " + pd.__version__)
print("numpy version: " + np.__version__)
print("matplotlib version: " + mpl.__version__)
print("gensim version: " + gensim.__version__)
print("sklearn version: " + sklearn.__version__)
print("nltk version: " + nltk.__version__)
print()

from google.colab import drive
drive.mount('/content/gdrive')

NUM_TESTING = 10000
TESTING = True
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
#
# ---------- versions ----------
#
# python version: 3.6.7 (default, Oct 22 2018, 11:32:17)
# [GCC 8.2.0]
# pandas version: 0.24.2
# numpy version: 1.16.4
# matplotlib version: 3.0.3
# gensim version: 3.6.0
# sklearn version: 0.21.2
# nltk version: 3.2.5
#
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %% [markdown]
# ### Downloading the data

# %%
print("\n---------- downloading data ----------\n")
DATA_PATH = '/content/gdrive/My Drive/Colab/stackoverflow-doc2vec/data/Questions.csv'

content = ""
with codecs.open(DATA_PATH, 'r', encoding='utf-8', errors='ignore') as file:
    content = file.read()
    
df = pd.read_csv(DATA_PATH, encoding = "ISO-8859-1")
# Out:
# ---------- downloading data ----------

# %% [markdown]
# ### Exploring the data

# %%
print("\n---------- exploring the data ----------\n")

# reduce data size if testing
if TESTING:
    print("Reduced data size to " + str(NUM_TESTING) + " entries")
    df = df[:NUM_TESTING]
    
print("Data shape: " + str(df.shape))
print("\ncolumn counts:\n" + str(df.count()))

num_missing = df.isnull().sum()
print("\nMissing values before:\n" + str(num_missing))

pd.set_option('display.expand_frame_repr', False)
print("\nFirst 5 data rows: \n" + str(df.head(n=5)))
# Out:
# ---------- exploring the data ----------
#
# Reduced data size to 10000 entries
# Data shape: (10000, 6)
#
# column counts:
# Id              10000
# OwnerUserId      9051
# CreationDate    10000
# Score           10000
# Title           10000
# Body            10000
# dtype: int64
#
# Missing values before:
# Id                0
# OwnerUserId     949
# CreationDate      0
# Score             0
# Title             0
# Body              0
# dtype: int64
#
# First 5 data rows:
#     Id  OwnerUserId          CreationDate  Score                                              Title                                               Body
# 0  469        147.0  2008-08-02T15:11:16Z     21  How can I find the full path to a font from it...  <p>I am using the Photoshop's javascript API t...
# 1  502        147.0  2008-08-02T17:01:58Z     27            Get a preview JPEG of a PDF on Windows?  <p>I have a cross-platform (Python) applicatio...
# 2  535        154.0  2008-08-02T18:43:54Z     40  Continuous Integration System for a Python Cod...  <p>I'm starting work on a hobby project with a...
# 3  594        116.0  2008-08-03T01:15:08Z     25     cx_Oracle: How do I iterate over a result set?  <p>There are several ways to iterate over a re...
# 4  683        199.0  2008-08-03T13:19:16Z     28  Using 'in' to match an attribute of Python obj...  <p>I don't remember whether I was dreaming or ...

# %% [markdown]
# ### Preparing Data

# %%
print("\n---------- preparing the data ----------\n")
# drop the columns we aren't looking at
df_dropped = df.drop(['Id', 'OwnerUserId', 'CreationDate', 'Score', 'Body'], axis = 1)
print("\nFirst 5 data rows after column dropping: \n" + str(df_dropped.head(n=5)))

# change to a numpy array
np_data = np.asarray(df_dropped)
print("\nData as an np array: \n" + str(np_data[0:5]))
print("\nData shape: " + str(np_data.shape) + "\n")

# removing punctuation and stop words, transforming to lower case and lemmatising
tokenizer = nltk.RegexpTokenizer(r'\w+')
stop_words = set(stopwords.words('english'))
lemmatizer = nltk.WordNetLemmatizer() 
docs = []
index = 0
for d in np_data:
    wordsList = tokenizer.tokenize(d[0])
    wordsList = [lemmatizer.lemmatize(w.lower()) for w in wordsList if w not in stop_words]
    docs.append(wordsList)

# tag the data
tagged_data = [TaggedDocument(doc, [i]) for i, doc in enumerate(docs)]
print("\nTagged data: " + str(tagged_data[0:5]))
# tagged_data = [TaggedDocument(words=word_tokenize(_d.lower()), tags=[str(i)]) for i, _d in enumerate(np_data)]
# Out:
# ---------- preparing the data ----------
#
#
# First 5 data rows after column dropping:
#                                                Title
# 0  How can I find the full path to a font from it...
# 1            Get a preview JPEG of a PDF on Windows?
# 2  Continuous Integration System for a Python Cod...
# 3     cx_Oracle: How do I iterate over a result set?
# 4  Using 'in' to match an attribute of Python obj...
#
# Data as an np array:
# [['How can I find the full path to a font from its display name on a Mac?']
#  ['Get a preview JPEG of a PDF on Windows?']
#  ['Continuous Integration System for a Python Codebase']
#  ['cx_Oracle: How do I iterate over a result set?']
#  ["Using 'in' to match an attribute of Python objects in an array"]]
#
# Data shape: (10000, 1)
#
#
# Tagged data: [TaggedDocument(words=['how', 'i', 'find', 'full', 'path', 'font', 'display', 'name', 'mac'], tags=[0]), TaggedDocument(words=['get', 'preview', 'jpeg', 'pdf', 'window'], tags=[1]), TaggedDocument(words=['continuous', 'integration', 'system', 'python', 'codebase'], tags=[2]), TaggedDocument(words=['cx_oracle', 'how', 'i', 'iterate', 'result', 'set'], tags=[3]), TaggedDocument(words=['using', 'match', 'attribute', 'python', 'object', 'array'], tags=[4])]

# %% [markdown]
# ### Training the model

# %%
print("\n---------- training the model ----------\n")
t = time()
num_epochs = 100
alpha = 0.025

# create model
model = Doc2Vec(vector_size=200, 
                window=5, 
                compute_loss=True,
                dm=1)
  
# build the vocab
model.build_vocab(tagged_data)

# train the vocab
model.train(tagged_data, total_examples=model.corpus_count, epochs=num_epochs, report_delay=1)
model.save("/content/gdrive/My Drive/Colab/stackoverflow-doc2vec/saved_model.model")
    
time_taken = round((time() - t) / 60, 2)
print("Time to train model: " + str(time_taken) + " mins")
# Out:
# 2019-06-08 19:20:41,415 : INFO : collecting all words and their counts
# 2019-06-08 19:20:41,417 : INFO : PROGRESS: at example #0, processed 0 words (0/s), 0 word types, 0 tags
# 2019-06-08 19:20:41,450 : INFO : collected 6286 word types and 10000 unique tags from a corpus of 10000 examples and 59751 words
# 2019-06-08 19:20:41,451 : INFO : Loading a fresh vocabulary
# 2019-06-08 19:20:41,460 : INFO : effective_min_count=5 retains 1635 unique words (26% of original 6286, drops 4651)
# 2019-06-08 19:20:41,460 : INFO : effective_min_count=5 leaves 52430 word corpus (87% of original 59751, drops 7321)
# 2019-06-08 19:20:41,469 : INFO : deleting the raw counts dictionary of 6286 items
# 2019-06-08 19:20:41,471 : INFO : sample=0.001 downsamples 47 most-common words
# 2019-06-08 19:20:41,472 : INFO : downsampling leaves estimated 40362 word corpus (77.0% of prior 52430)
# 2019-06-08 19:20:41,478 : INFO : estimated required memory for 1635 words and 200 dimensions: 11433500 bytes
# 2019-06-08 19:20:41,478 : INFO : resetting layer weights
# ---------- training the model ----------
# 2019-06-08 19:20:41,606 : INFO : training model with 3 workers on 1635 vocabulary and 200 features, using sg=0 hs=0 sample=0.001 negative=5 window=5
# 2019-06-08 19:20:42,074 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-06-08 19:20:42,076 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-06-08 19:20:42,084 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-06-08 19:20:42,086 : INFO : EPOCH - 1 : training on 59751 raw words (50388 effective words) took 0.5s, 107374 effective words/s
# 2019-06-08 19:20:42,529 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-06-08 19:20:42,531 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-06-08 19:20:42,540 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-06-08 19:20:42,541 : INFO : EPOCH - 2 : training on 59751 raw words (50394 effective words) took 0.4s, 113472 effective words/s
# 2019-06-08 19:20:43,012 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-06-08 19:20:43,019 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-06-08 19:20:43,024 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-06-08 19:20:43,025 : INFO : EPOCH - 3 : training on 59751 raw words (50402 effective words) took 0.5s, 105876 effective words/s
# 2019-06-08 19:20:43,480 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-06-08 19:20:43,486 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-06-08 19:20:43,492 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-06-08 19:20:43,493 : INFO : EPOCH - 4 : training on 59751 raw words (50448 effective words) took 0.5s, 110270 effective words/s
# 2019-06-08 19:20:43,929 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-06-08 19:20:43,939 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-06-08 19:20:43,947 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-06-08 19:20:43,948 : INFO : EPOCH - 5 : training on 59751 raw words (50344 effective words) took 0.4s, 113365 effective words/s
# 2019-06-08 19:20:44,398 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-06-08 19:20:44,403 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-06-08 19:20:44,409 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-06-08 19:20:44,410 : INFO : EPOCH - 6 : training on 59751 raw words (50439 effective words) took 0.5s, 110993 effective words/s
# 2019-06-08 19:20:44,850 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-06-08 19:20:44,861 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-06-08 19:20:44,870 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-06-08 19:20:44,870 : INFO : EPOCH - 7 : training on 59751 raw words (50269 effective words) took 0.5s, 111688 effective words/s
# 2019-06-08 19:20:45,340 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-06-08 19:20:45,344 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-06-08 19:20:45,350 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-06-08 19:20:45,351 : INFO : EPOCH - 8 : training on 59751 raw words (50441 effective words) took 0.5s, 106715 effective words/s
# 2019-06-08 19:20:45,801 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-06-08 19:20:45,815 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-06-08 19:20:45,820 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-06-08 19:20:45,821 : INFO : EPOCH - 9 : training on 59751 raw words (50388 effective words) took 0.5s, 109777 effective words/s
# 2019-06-08 19:20:46,263 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-06-08 19:20:46,275 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-06-08 19:20:46,279 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-06-08 19:20:46,281 : INFO : EPOCH - 10 : training on 59751 raw words (50319 effective words) took 0.4s, 111942 effective words/s
# 2019-06-08 19:20:46,725 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-06-08 19:20:46,732 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-06-08 19:20:46,735 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-06-08 19:20:46,736 : INFO : EPOCH - 11 : training on 59751 raw words (50347 effective words) took 0.4s, 113307 effective words/s
# 2019-06-08 19:20:47,189 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-06-08 19:20:47,198 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-06-08 19:20:47,205 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-06-08 19:20:47,205 : INFO : EPOCH - 12 : training on 59751 raw words (50366 effective words) took 0.5s, 110310 effective words/s
# 2019-06-08 19:20:47,651 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-06-08 19:20:47,664 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-06-08 19:20:47,669 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-06-08 19:20:47,670 : INFO : EPOCH - 13 : training on 59751 raw words (50393 effective words) took 0.5s, 111088 effective words/s
# 2019-06-08 19:20:48,113 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-06-08 19:20:48,120 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-06-08 19:20:48,126 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-06-08 19:20
: INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-06-08 19:21:04,784 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-06-08 19:21:04,786 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-06-08 19:21:04,788 : INFO : EPOCH - 50 : training on 59751 raw words (50325 effective words) took 0.5s, 109309 effective words/s
# 2019-06-08 19:21:05,247 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-06-08 19:21:05,253 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-06-08 19:21:05,261 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-06-08 19:21:05,262 : INFO : EPOCH - 51 : training on 59751 raw words (50266 effective words) took 0.5s, 108885 effective words/s
# 2019-06-08 19:21:05,738 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-06-08 19:21:05,753 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-06-08 19:21:05,759 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-06-08 19:21:05,759 : INFO : EPOCH - 52 : training on 59751 raw words (50377 effective words) took 0.5s, 102964 effective words/s
# 2019-06-08 19:21:06,216 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-06-08 19:21:06,225 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-06-08 19:21:06,234 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-06-08 19:21:06,235 : INFO : EPOCH - 53 : training on 59751 raw words (50445 effective words) took 0.5s, 108113 effective words/s
# 2019-06-08 19:21:06,694 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-06-08 19:21:06,700 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-06-08 19:21:06,706 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-06-08 19:21:06,708 : INFO : EPOCH - 54 : training on 59751 raw words (50433 effective words) took 0.5s, 108480 effective words/s
# 2019-06-08 19:21:07,170 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-06-08 19:21:07,177 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-06-08 19:21:07,182 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-06-08 19:21:07,183 : INFO : EPOCH - 55 : training on 59751 raw words (50299 effective words) took 0.5s, 108381 effective words/s
# 2019-06-08 19:21:07,651 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-06-08 19:21:07,656 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-06-08 19:21:07,667 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-06-08 19:21:07,668 : INFO : EPOCH - 56 : training on 59751 raw words (50459 effective words) took 0.5s, 106227 effective words/s
# 2019-06-08 19:21:08,114 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-06-08 19:21:08,121 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-06-08 19:21:08,128 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-06-08 19:21:08,129 : INFO : EPOCH - 57 : training on 59751 raw words (50293 effective words) took 0.5s, 111592 effective words/s
# 2019-06-08 19:21:08,583 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-06-08 19:21:08,588 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-06-08 19:21:08,591 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-06-08 19:21:08,592 : INFO : EPOCH - 58 : training on 59751 raw words (50380 effective words) took 0.5s, 111422 effective words/s
# 2019-06-08 19:21:09,073 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-06-08 19:21:09,079 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-06-08 19:21:09,082 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-06-08 19:21:09,083 : INFO : EPOCH - 59 : training on 59751 raw words (50470 effective words) took 0.5s, 105682 effective words/s
# 2019-06-08 19:21:09,555 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-06-08 19:21:09,561 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-06-08 19:21:09,568 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-06-08 19:21:09,569 : INFO : EPOCH - 60 : training on 59751 raw words (50369 effective words) took 0.5s, 106595 effective words/s
# 2019-06-08 19:21:10,032 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-06-08 19:21:10,039 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-06-08 19:21:10,045 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-06-08 19:21:10,046 : INFO : EPOCH - 61 : training on 59751 raw words (50355 effective words) took 0.5s, 108321 effective words/s
# 2019-06-08 19:21:10,483 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-06-08 19:21:10,490 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-06-08 19:21:10,495 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-06-08 19:21:10,496 : INFO : EPOCH - 62 : training on 59751 raw words (50389 effective words) took 0.4s, 114592 effective words/s
# 2019-06-08 19:21:10,959 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-06-08 19:21:10,969 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-06-08 19:21:10,973 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-06-08 19:21:10,973 : INFO : EPOCH - 63 : training on 59751 raw words (50373 effective words) took 0.5s, 108135 effective words/s
# 2019-06-08 19:21:11,429 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-06-08 19:21:11,437 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-06-08 19:21:11,441 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-06-08 19:21:11,442 : INFO : EPOCH - 64 : training on 59751 raw words (50434 effective words) took 0.5s, 110324 effective words/s
# 2019-06-08 19:21:11,905 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-06-08 19:21:11,911 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-06-08 19:21:11,914 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-06-08 19:21:11,915 : INFO : EPOCH - 65 : training on 59751 raw words (50490 effective words) took 0.5s, 109468 effective words/s
# 2019-06-08 19:21:12,374 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-06-08 19:21:12,386 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-06-08 19:21:12,393 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-06-08 19:21:12,394 : INFO : EPOCH - 66 : training on 59751 raw words (50366 effective words) took 0.5s, 107751 effective words/s
# 2019-06-08 19:21:12,837 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-06-08 19:21:12,843 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-06-08 19:21:12,849 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-06-08 19:21:12,850 : INFO : EPOCH - 67 : training on 59751 raw words (50378 effective words) took 0.4s, 115428 effective words/s
# 2019-06-08 19:21:13,311 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-06-08 19:21:13,318 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-06-08 19:21:13,327 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-06-08 19:21:13,328 : INFO : EPOCH - 68 : training on 59751 raw words (50325 effective words) took 0.5s, 108019 effective words/s
# 2019-06-08 19:21:13,789 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-06-08 19:21:13,796 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-06-08 19:21:13,800 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-06-08 19:21:13,801 : INFO : EPOCH - 69 : training on 59751 raw words (50360 effective words) took 0.5s, 109049 effective words/s
# 2019-06-08 19:21:14,244 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-06-08 19:21:14,249 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-06-08 19:21:14,255 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-06-08 19:21:14,255 : INFO : EPOCH - 70 : training on 59751 raw words (50369 effective words) took 0.4s, 113300 effective words/s
# 2019-06-08 19:21:14,684 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-06-08 19:21:14,700 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-06-08 19:21:14,708 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-06-08 19:21:14,709 : INFO : EPOCH - 71 : training on 59751 raw words (50282 effective words) took 0.4s, 113611 effective words/s
# 2019-06-08 19:21:15,158 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-06-08 19:21:15,169 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-06-08 19:21:15,171 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-06-08 19:21:15,172 : INFO : EPOCH - 72 : training on 59751 raw words (50403 effective words) took 0.5s, 111085 effective words/s
# 2019-06-08 19:21:15,618 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-06-08 19:21:15,629 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-06-08 19:21:15,634 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-06-08 19:21:15,635 : INFO : EPOCH - 73 : training on 59751 raw words (50421 effective words) took 0.5s, 111264 effective words/s
# 2019-06-08 19:21:16,088 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-06-08 19:21:16,095 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-06-08 19:21:16,099 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-06-08 19:21:16,100 : INFO : EPOCH - 74 : training on 59751 raw words (50279 effective words) took 0.5s, 110557 effective words/s
# 2019-06-08 19:21:16,543 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-06-08 19:21:16,550 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-06-08 19:21:16,555 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-06-08 19:21:16,556 : INFO : EPOCH - 75 : training on 59751 raw words (50347 effective words) took 0.4s, 113254 effective words/s
# 2019-06-08 19:21:17,009 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-06-08 19:21:17,018 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-06-08 19:21:17,024 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-06-08 19:21:17,025 : INFO : EPOCH - 76 : training on 59751 raw words (50422 effective words) took 0.5s, 109737 effective words/s
# 2019-06-08 19:21:17,478 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-06-08 19:21:17,484 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-06-08 19:21:17,490 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-06-08 19:21:17,491 : INFO : EPOCH - 77 : training on 59751 raw words (50376 effective words) took 0.5s, 110459 effective words/s
# 2019-06-08 19:21:17,932 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-06-08 19:21:17,940 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-06-08 19:21:17,945 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-06-08 19:21:17,945 : INFO : EPOCH - 78 : training on 59751 raw words (50324 effective words) took 0.4s, 113419 effective words/s
# 2019-06-08 19:21:18,385 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-06-08 19:21:18,390 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-06-08 19:21:18,394 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-06-08 19:21:18,395 : INFO : EPOCH - 79 : training on 59751 raw words (50406 effective words) took 0.4s, 114451 effective words/s
# 2019-06-08 19:21:18,847 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-06-08 19:21:18,855 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-06-08 19:21:18,860 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-06-08 19:21:18,861 : INFO : EPOCH - 80 : training on 59751 raw words (50318 effective words) took 0.5s, 110704 effective words/s
# 2019-06-08 19:21:19,309 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-06-08 19:21:19,318 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-06-08 19:21:19,324 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-06-08 19:21:19,325 : INFO : EPOCH - 81 : training on 59751 raw words (50314 effective words) took 0.5s, 111091 effective words/s
# 2019-06-08 19:21:19,787 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-06-08 19:21:19,793 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-06-08 19:21:19,795 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-06-08 19:21:19,796 : INFO : EPOCH - 82 : training on 59751 raw words (50311 effective words) took 0.5s, 109085 effective words/s
# 2019-06-08 19:21:20,236 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-06-08 19:21:20,240 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-06-08 19:21:20,246 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-06-08 19:21:20,247 : INFO : EPOCH - 83 : training on 59751 raw words (50399 effective words) took 0.4s, 114732 effective words/s
# 2019-06-08 19:21:20,687 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-06-08 19:21:20,699 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-06-08 19:21:20,701 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-06-08 19:21:20,702 : INFO : EPOCH - 84 : training on 59751 raw words (50249 effective words) took 0.4s, 113307 effective words/s
# 2019-06-08 19:21:21,170 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-06-08 19:21:21,175 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-06-08 19:21:21,179 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-06-08 19:21:21,180 : INFO : EPOCH - 85 : training on 59751 raw words (50177 effective words) took 0.5s, 107615 effective words/s
# 2019-06-08 19:21:21,637 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-06-08 19:21:21,642 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-06-08 19:21:21,650 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-06-08 19:21:21,650 : INFO : EPOCH - 86 : training on 59751 raw words (50416 effective words) took 0.5s, 110084 effective words/s
# 2019-06-08 19:21:22,098 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-06-08 19:21:22,104 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-06-08 19:21:22,107 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-06-08 19:21:22,108 : INFO : EPOCH - 87 : training on 59751 raw words (50312 effective words) took 0.4s, 112702 effective words/s
# 2019-06-08 19:21:22,539 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-06-08 19:21:22,552 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-06-08 19:21:22,558 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-06-08 19:21:22,559 : INFO : EPOCH - 88 : training on 59751 raw words (50304 effective words) took 0.4s, 114568 effective words/s
# 2019-06-08 19:21:23,023 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-06-08 19:21:23,027 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-06-08 19:21:23,028 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-06-08 19:21:23,030 : INFO : EPOCH - 89 : training on 59751 raw words (50249 effective words) took 0.5s, 109830 effective words/s
# 2019-06-08 19:21:23,473 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-06-08 19:21:23,483 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-06-08 19:21:23,488 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-06-08 19:21:23,489 : INFO : EPOCH - 90 : training on 59751 raw words (50512 effective words) took 0.4s, 113411 effective words/s
# 2019-06-08 19:21:23,933 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-06-08 19:21:23,939 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-06-08 19:21:23,943 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-06-08 19:21:23,944 : INFO : EPOCH - 91 : training on 59751 raw words (50477 effective words) took 0.4s, 112810 effective words/s
# 2019-06-08 19:21:24,389 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-06-08 19:21:24,396 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-06-08 19:21:24,402 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-06-08 19:21:24,402 : INFO : EPOCH - 92 : training on 59751 raw words (50264 effective words) took 0.4s, 112482 effective words/s
# 2019-06-08 19:21:24,838 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-06-08 19:21:24,854 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-06-08 19:21:24,861 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-06-08 19:21:24,862 : INFO : EPOCH - 93 : training on 59751 raw words (50445 effective words) took 0.4s, 112444 effective words/s
# 2019-06-08 19:21:25,297 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-06-08 19:21:25,310 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-06-08 19:21:25,315 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-06-08 19:21:25,316 : INFO : EPOCH - 94 : training on 59751 raw words (50338 effective words) took 0.4s, 113584 effective words/s
# 2019-06-08 19:21:25,753 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-06-08 19:21:25,758 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-06-08 19:21:25,765 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-06-08 19:21:25,766 : INFO : EPOCH - 95 : training on 59751 raw words (50296 effective words) took 0.4s, 114621 effective words/s
# 2019-06-08 19:21:26,200 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-06-08 19:21:26,212 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-06-08 19:21:26,216 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-06-08 19:21:26,217 : INFO : EPOCH - 96 : training on 59751 raw words (50277 effective words) took 0.4s, 114194 effective words/s
# 2019-06-08 19:21:26,654 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-06-08 19:21:26,662 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-06-08 19:21:26,668 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-06-08 19:21:26,669 : INFO : EPOCH - 97 : training on 59751 raw words (50349 effective words) took 0.4s, 113752 effective words/s
# 2019-06-08 19:21:27,121 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-06-08 19:21:27,127 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-06-08 19:21:27,131 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-06-08 19:21:27,132 : INFO : EPOCH - 98 : training on 59751 raw words (50364 effective words) took 0.5s, 111596 effective words/s
# 2019-06-08 19:21:27,577 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-06-08 19:21:27,585 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-06-08 19:21:27,589 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-06-08 19:21:27,591 : INFO : EPOCH - 99 : training on 59751 raw words (50460 effective words) took 0.4s, 112816 effective words/s
# 2019-06-08 19:21:28,020 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-06-08 19:21:28,035 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-06-08 19:21:28,037 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-06-08 19:21:28,038 : INFO : EPOCH - 100 : training on 59751 raw words (50439 effective words) took 0.4s, 115312 effective words/s
# 2019-06-08 19:21:28,039 : INFO : training on a 5975100 raw words (5036132 effective words) took 46.4s, 108462 effective words/s
# 2019-06-08 19:21:28,040 : INFO : saving Doc2Vec object under /content/gdrive/My Drive/Colab/stackoverflow-doc2vec/saved_model.model, separately None
# /usr/local/lib/python3.6/dist-packages/smart_open/smart_open_lib.py:398: UserWarning: This function is deprecated, use smart_open.open instead. See the migration notes for details: https://github.com/RaRe-Technologies/smart_open/blob/master/README.rst#migrating-to-the-new-open-function
#   'See the migration notes for details: %s' % _MIGRATION_NOTES_URL
# 2019-06-08 19:21:28,173 : INFO : saved /content/gdrive/My Drive/Colab/stackoverflow-doc2vec/saved_model.model
# Time to train model: 0.78 mins

# %% [markdown]
# ### Exploring the model

# %%
print("\n---------- Exploring the model ----------\n")
model = Doc2Vec.load("/content/gdrive/My Drive/Colab/stackoverflow-doc2vec/saved_model.model")

# choosing a test phrase to find a similar document to
test_phrase = 'list comprehension'
print("Testing the phrase: '", test_phrase, "'")
test_data = word_tokenize(test_phrase.lower())
inferred_phrase_vector = model.infer_vector(test_data)
print("Inferred vector for phrase: ", inferred_phrase_vector)

# finding the most similar documents to the phrase
print()
print("10 most similar docs")
t = time()
similar_docs = model.docvecs.most_similar([inferred_phrase_vector])
time_taken = round((time() - t) / 60, 2)
print("Time to find 10 most similar docs: ", time_taken, " mins")

print("Most similar docs (tags and scores): ", similar_docs)

print("Most similar docs (scores and text):")
for doc in similar_docs:
    tag = doc[0]
    score = doc[1]
    text = np_data[tag][0]
    print("score:", score, " doc:", text)

# now looking at similarity to all documents
print()
print(model.docvecs.count, "most similar docs")
print("Time to find " + str(model.docvecs.count) + " most similar docs")
t = time()
similar_docs = model.docvecs.most_similar([inferred_phrase_vector], topn=model.docvecs.count)
time_taken = round((time() - t) / 60, 2)
print("Time to find " + str(model.docvecs.count) + " similar docs: " + str(time_taken) + " mins")

print("Most similar doc: ", np_data[similar_docs[0][0]]) 
print("Median similar doc: ", np_data[similar_docs[int(model.docvecs.count/2)][0]])
print("Least similar doc: ", np_data[similar_docs[-1][0]])
print()
# Out:
# 2019-06-08 19:22:05,077 : INFO : loading Doc2Vec object from /content/gdrive/My Drive/Colab/stackoverflow-doc2vec/saved_model.model
# /usr/local/lib/python3.6/dist-packages/smart_open/smart_open_lib.py:398: UserWarning: This function is deprecated, use smart_open.open instead. See the migration notes for details: https://github.com/RaRe-Technologies/smart_open/blob/master/README.rst#migrating-to-the-new-open-function
#   'See the migration notes for details: %s' % _MIGRATION_NOTES_URL
# 2019-06-08 19:22:05,180 : INFO : loading vocabulary recursively from /content/gdrive/My Drive/Colab/stackoverflow-doc2vec/saved_model.model.vocabulary.* with mmap=None
# 2019-06-08 19:22:05,182 : INFO : loading trainables recursively from /content/gdrive/My Drive/Colab/stackoverflow-doc2vec/saved_model.model.trainables.* with mmap=None
# 2019-06-08 19:22:05,183 : INFO : loading wv recursively from /content/gdrive/My Drive/Colab/stackoverflow-doc2vec/saved_model.model.wv.* with mmap=None
# 2019-06-08 19:22:05,184 : INFO : loading docvecs recursively from /content/gdrive/My Drive/Colab/stackoverflow-doc2vec/saved_model.model.docvecs.* with mmap=None
# 2019-06-08 19:22:05,185 : INFO : loaded /content/gdrive/My Drive/Colab/stackoverflow-doc2vec/saved_model.model
# 2019-06-08 19:22:05,201 : INFO : precomputing L2-norms of doc weight vectors
# ---------- Exploring the model ----------
#
# Testing the phrase: ' list comprehension '
# Inferred vector for phrase:  [-0.0303454   0.03146004  0.06117353  0.11697804  0.15151669  0.08276034
#  -0.09367646  0.02419818  0.03362042 -0.17787649 -0.12787664 -0.05211365
#   0.16136287  0.09925481  0.19775678 -0.18140951 -0.01212998  0.03110356
#  -0.09260952 -0.18974523  0.13384499  0.00079723 -0.04463546 -0.0570041
#   0.0812666   0.13048825  0.1623901  -0.04154849  0.0723967  -0.04093298
#   0.06035692 -0.11277607  0.11763982 -0.02965449  0.072163    0.09545857
#  -0.07982928 -0.0394634  -0.06494092  0.07373034  0.14936884 -0.19790508
#   0.00925783 -0.06225413  0.14222968  0.03906593 -0.05303317 -0.2320815
#  -0.1320135  -0.09805014 -0.0880162   0.0162906  -0.09882345  0.13940069
#  -0.03867751 -0.08261397  0.02370062  0.1531846  -0.05535223  0.08236048
#   0.10152145 -0.03202575 -0.03014833  0.09819843  0.01812522  0.00866298
#  -0.15402807 -0.16700388 -0.11383224  0.23744929  0.02000295 -0.04555642
#  -0.11222352 -0.06503293 -0.02915816  0.02655124  0.14173013  0.14671427
#  -0.10526912  0.09877235  0.17508237 -0.01288996 -0.11758714  0.09600944
#   0.11359972  0.02429381 -0.09729718  0.11447799  0.1088584   0.00986238
#  -0.07238393  0.04572114 -0.04686126  0.0925087  -0.03135103 -0.07384101
#   0.2828071  -0.00158945 -0.00870885 -0.08333679 -0.11088467  0.09927846
#  -0.1966902   0.26247647  0.04509725  0.2759197  -0.06905945  0.29631475
#  -0.15224706  0.01164718  0.0358561  -0.13278936  0.03461958  0.0729028
#  -0.00657139 -0.11366323  0.2227425  -0.0890901  -0.14899762  0.04274138
#  -0.14784773  0.02187305  0.15493192  0.0556052   0.06060688  0.16957557
#  -0.00661774 -0.15397714  0.11986227 -0.2014854   0.12598425  0.04406931
#  -0.00900442  0.05209361 -0.03715434  0.1176273   0.03777566  0.16037667
#  -0.03241561 -0.11193279  0.23976701 -0.00326694  0.13955589 -0.15024889
#  -0.11283477 -0.01612333  0.02064608 -0.00704138 -0.18921249 -0.19107787
#  -0.05107708 -0.03494149  0.14055638  0.20339282 -0.20465894 -0.06828275
#  -0.03905345 -0.102804   -0.23076476  0.0130603  -0.20674923 -0.24142593
#  -0.24442495  0.10769221 -0.04386091 -0.21013579 -0.04863234 -0.06148924
#  -0.02878037  0.0782951  -0.04533412  0.03008786 -0.00856918  0.06311051
#  -0.08591545  0.05612891  0.23330657 -0.07486544  0.05483974  0.03644493
#  -0.03280015  0.01890128 -0.10530537  0.15754218 -0.10053071  0.01792635
#   0.03753671 -0.05178165 -0.08998786 -0.05862626 -0.03365524  0.08783851
#  -0.08470664  0.09765614 -0.16705218  0.01169768  0.20542578  0.12157403
#   0.12424068  0.05105261]
#
# 10 most similar docs
# Time to find 10 most similar docs:  0.0  mins
# Most similar docs (tags and scores):  [(6971, 0.8772432804107666), (2319, 0.8763458728790283), (4704, 0.8721120357513428), (1694, 0.8634964823722839), (9572, 0.8495418429374695), (6608, 0.8342247605323792), (1398, 0.7891718149185181), (6880, 0.7883541584014893), (8375, 0.7553553581237793), (938, 0.7393959760665894)]
# Most similar docs (scores and text):
# score: 0.8772432804107666  doc: List comprehension python
# score: 0.8763458728790283  doc: python: list comprehension tactics
# score: 0.8721120357513428  doc: List Comprehensions and Conditions?
# score: 0.8634964823722839  doc: generator comprehension
# score: 0.8495418429374695  doc: Verbose list comprehension in Python
# score: 0.8342247605323792  doc: python list comprehensions; compressing a list of lists?
# score: 0.7891718149185181  doc: How to indent Python list-comprehensions?
# score: 0.7883541584014893  doc: Perl equivalent of (Python-) list comprehension
# score: 0.7553553581237793  doc: Mapping a nested list with List Comprehension in Python?
# score: 0.7393959760665894  doc: Unexpected list comprehension behaviour in Python
#
# 10000 most similar docs
# Time to find 10000 most similar docs
# Time to find 10000 similar docs: 0.0 mins
# Most similar doc:  ['List comprehension python']
# Median similar doc:  ['Change keyboard locks in Python']
# Least similar doc:  ['Disable pixmap background defined by GTK theme per application']
# /usr/local/lib/python3.6/dist-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
